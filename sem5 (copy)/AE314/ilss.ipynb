# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("ilss.csv")

# %% [markdown]
# x and y are reduced extension and load from data which are extension-extension[0] and load-load[0] respectively

# %%
x=(df['extensionr']) 
y=(df['loadr'])

# %%
plt.plot(x,y)
plt.xlabel("Extension")
plt.ylabel("Load")
plt.show()

# %% [markdown]
# It is observed that the till 1.5mm the material is being extended very easily with minimum load while after that for small extensions we needed to apply very high loads which is varying linearly with a very high slope
#
# *** The graph is showing reduced load as well as extension and because of this: $Load_{actual} = Load_{graph} + 339.85$
